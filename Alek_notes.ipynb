# %% [markdown]
# ## APIs for economics data
#
# ### Interest rates, inflation
#
# The World Bank : https://datahelpdesk.worldbank.org/knowledgebase/topics/125589
#
#
# #### Indicators
#
# FP.CPI.TOTL.ZG: the indicator for inflation rate
#
# FR.INR.RINR: Real interest rate (%), which is adjusted for inflation.
#
# FR.INR.LEND: Lending interest rate (%), which reflects the rate charged by banks on loans to prime customers.
#
#
# ##### Syntax
# {data} = date=2010:2023
#
# General url "https://api.worldbank.org/v2/country/{country i.e. US}/indicator/{indicator}?{date}?format=json"

# %%
import requests
import json


# FP.CPI.TOTL.ZG is the indicator for inflation rate
url = "https://api.worldbank.org/v2/country/US/indicator/FP.CPI.TOTL.ZG?format=json"
response = requests.get(url)
data = response.json()

# Print the data
print(json.dumps(data, indent=2))
# Out:
# [
#   {
#     "page": 1,
#     "pages": 2,
#     "per_page": 50,
#     "total": 64,
#     "sourceid": "2",
#     "lastupdated": "2024-10-24"
#   },
#   [
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2023",
#       "value": 4.11633838374488,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2022",
#       "value": 8.00279982052121,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2021",
#       "value": 4.69785886363742,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2020",
#       "value": 1.23358439630629,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2019",
#       "value": 1.81221007526021,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2018",
#       "value": 2.44258329692817,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2017",
#       "value": 2.13011000365961,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2016",
#       "value": 1.26158320570536,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2015",
#       "value": 0.118627135552451,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2014",
#       "value": 1.62222297740817,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2013",
#       "value": 1.46483265562717,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2012",
#       "value": 2.06933726526067,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2011",
#       "value": 3.156841568622,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2010",
#       "value": 1.6400434423899,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2009",
#       "value": -0.355546266299747,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2008",
#       "value": 3.839100296651,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2007",
#       "value": 2.85267248150138,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2006",
#       "value": 3.22594410070404,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2005",
#       "value": 3.3927468454955,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2004",
#       "value": 2.67723669309172,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2003",
#       "value": 2.27009497336115,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2002",
#       "value": 1.58603162650601,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2001",
#       "value": 2.82617111885407,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "2000",
#       "value": 3.37685727149929,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1999",
#       "value": 2.18802719697358,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1998",
#       "value": 1.55227909874364,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1997",
#       "value": 2.33768993730735,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1996",
#       "value": 2.93120419993441,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1995",
#       "value": 2.80541968853662,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1994",
#       "value": 2.60744159215453,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1993",
#       "value": 2.95165696638559,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1992",
#       "value": 3.02881967814969,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1991",
#       "value": 4.23496396453849,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1990",
#       "value": 5.39795643990325,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1989",
#       "value": 4.82700303008944,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1988",
#       "value": 4.07774110744413,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1987",
#       "value": 3.6645632175169,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1986",
#       "value": 1.89804772234276,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1985",
#       "value": 3.54564415209365,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1984",
#       "value": 4.30053547523429,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1983",
#       "value": 3.21243523316065,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1982",
#       "value": 6.13142700027493,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1981",
#       "value": 10.3347153402771,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1980",
#       "value": 13.5492019749684,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1979",
#       "value": 11.2544711292795,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1978",
#       "value": 7.63096383885606,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1977",
#       "value": 6.5016839947284,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1976",
#       "value": 5.74481263549085,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1975",
#       "value": 9.14314686496535,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     },
#     {
#       "indicator": {
#         "id": "FP.CPI.TOTL.ZG",
#         "value": "Inflation, consumer prices (annual %)"
#       },
#       "country": {
#         "id": "US",
#         "value": "United States"
#       },
#       "countryiso3code": "USA",
#       "date": "1974",
#       "value": 11.0548048048048,
#       "unit": "",
#       "obs_status": "",
#       "decimal": 1
#     }
#   ]
# ]

# %% [markdown]
# ### Economics data
# FRED : https://fred.stlouisfed.org/docs/api/api_key.html
#
# api_key = "107f3d255ade491b6e850f8e1e4b33c6"
#
# #### Indicators
# MSPUS: Median Sales Price of Houses Sold for the United States.
#
# ASPUS: Average Sales Price of Houses Sold for the United States.
#
# ATNHPIUS{State Code}****: All-Transactions House Price Index for individual states (e.g., ATNHPIUS06 for California).

# %%
import requests
import json

# Set up the FRED API request URL for U.S. Median Sales Price
api_key = "107f3d255ade491b6e850f8e1e4b33c6"
# Define the API endpoint and your API key
series_id = "ASPUS"  # Example for California
start_date = "2015-01-01"  # Start date
end_date = "2023-01-01"  # End date
limit = 100000  # Maximum records to retrieve

# Construct the API URL with limit and date range
url = f"https://api.stlouisfed.org/fred/series/observations?series_id={series_id}&observation_start={start_date}&observation_end={end_date}&limit={limit}&api_key={api_key}&file_type=json"

# Make the API request
response = requests.get(url)
data = response.json()

# Print the data
print(json.dumps(data, indent=2))
# Out:
# {
#   "realtime_start": "2024-11-09",
#   "realtime_end": "2024-11-09",
#   "observation_start": "2014-01-01",
#   "observation_end": "2023-01-01",
#   "units": "lin",
#   "output_type": 1,
#   "file_type": "json",
#   "order_by": "observation_date",
#   "sort_order": "asc",
#   "count": 37,
#   "offset": 0,
#   "limit": 100000,
#   "observations": [
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2014-01-01",
#       "value": "331400"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2014-04-01",
#       "value": "340600"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2014-07-01",
#       "value": "340400"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2014-10-01",
#       "value": "369400"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2015-01-01",
#       "value": "348000"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2015-04-01",
#       "value": "339700"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2015-07-01",
#       "value": "347400"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2015-10-01",
#       "value": "366700"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2016-01-01",
#       "value": "357000"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2016-04-01",
#       "value": "357900"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2016-07-01",
#       "value": "358800"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2016-10-01",
#       "value": "364900"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2017-01-01",
#       "value": "374800"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2017-04-01",
#       "value": "376900"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2017-07-01",
#       "value": "373200.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2017-10-01",
#       "value": "399700.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2018-01-01",
#       "value": "374600.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2018-04-01",
#       "value": "378400.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2018-07-01",
#       "value": "392900.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2018-10-01",
#       "value": "384000.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2019-01-01",
#       "value": "375500.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2019-04-01",
#       "value": "376700.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2019-07-01",
#       "value": "382700.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2019-10-01",
#       "value": "384600.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2020-01-01",
#       "value": "383000.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2020-04-01",
#       "value": "371100.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2020-07-01",
#       "value": "400600.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2020-10-01",
#       "value": "396900.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2021-01-01",
#       "value": "417400.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2021-04-01",
#       "value": "428600.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2021-07-01",
#       "value": "468000.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2021-10-01",
#       "value": "496700.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2022-01-01",
#       "value": "499300.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2022-04-01",
#       "value": "525100.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2022-07-01",
#       "value": "520300.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2022-10-01",
#       "value": "521000.0"
#     },
#     {
#       "realtime_start": "2024-11-09",
#       "realtime_end": "2024-11-09",
#       "date": "2023-01-01",
#       "value": "505300.0"
#     }
#   ]
# }

# %%
import yfinance as yf

# Define the stock ticker symbol (e.g., 'AAPL' for Apple)
ticker = 'AAPL'

# Define the start and end date
start_date = '2020-01-01'
end_date = '2024-01-01'

# Fetch historical data
stock_data = yf.download(ticker, start=start_date, end=end_date)

# Print the retrieved data
print(stock_data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2020-01-02 00:00:00+00:00   72.796028   75.087502   75.150002   73.797501
# 2020-01-03 00:00:00+00:00   72.088318   74.357498   75.144997   74.125000
# 2020-01-06 00:00:00+00:00   72.662704   74.949997   74.989998   73.187500
# 2020-01-07 00:00:00+00:00   72.320969   74.597504   75.224998   74.370003
# 2020-01-08 00:00:00+00:00   73.484360   75.797501   76.110001   74.290001
# ...                               ...         ...         ...         ...
# 2023-12-22 00:00:00+00:00  192.656189  193.600006  195.410004  192.970001
# 2023-12-26 00:00:00+00:00  192.108856  193.050003  193.889999  192.830002
# 2023-12-27 00:00:00+00:00  192.208359  193.149994  193.500000  191.089996
# 2023-12-28 00:00:00+00:00  192.636261  193.580002  194.660004  193.169998
# 2023-12-29 00:00:00+00:00  191.591385  192.529999  194.399994  191.729996
#
# Price                            Open     Volume
# Ticker                           AAPL       AAPL
# Date
# 2020-01-02 00:00:00+00:00   74.059998  135480400
# 2020-01-03 00:00:00+00:00   74.287498  146322800
# 2020-01-06 00:00:00+00:00   73.447502  118387200
# 2020-01-07 00:00:00+00:00   74.959999  108872000
# 2020-01-08 00:00:00+00:00   74.290001  132079200
# ...                               ...        ...
# 2023-12-22 00:00:00+00:00  195.179993   37122800
# 2023-12-26 00:00:00+00:00  193.610001   28919300
# 2023-12-27 00:00:00+00:00  192.490005   48087700
# 2023-12-28 00:00:00+00:00  194.139999   34049900
# 2023-12-29 00:00:00+00:00  193.899994   42628800
#
# [1006 rows x 6 columns]
